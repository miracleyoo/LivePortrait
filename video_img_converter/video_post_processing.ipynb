# %%
import os
import cv2
import os.path as osp
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
def video_to_images(input_video_path, 
                    split_image_root='/prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images',
                    driving_video_ver=1):
    # input_video_path = '/prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/aanbunat--atalie.mp4'
    # split_image_root = '/prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images'
    # driving_video_ver = 1

    os.makedirs(split_image_root, exist_ok=True)

    if driving_video_ver == 1:
        image_list_record_root = '/prj/qct/mmrd-cv/wonderland_data/3DFR_Data_wrap4d/Pair_man/PAC/meta/train'
    elif driving_video_ver == 2:
        image_list_record_root = '/mnt/QPFA-LV/dataset/LightCage_Process_MV_Data/PAC_Add_Nose/meta'

    stem = osp.basename(input_video_path).split('.')[0]
    source_name = stem.split('--')[0]
    driving_name = stem.split('--')[1]
    # print(stem, source_name, driving_name)
    meta_file = osp.join(image_list_record_root, f'data_parsed_List_{driving_name}_man_process_list_train.csv')
    image_filename_list = pd.read_csv(meta_file)['tar_bg'].tolist()

    out_driving_folder = osp.join(split_image_root, driving_name, source_name)
    os.makedirs(out_driving_folder, exist_ok=True)

    cap = cv2.VideoCapture(input_video_path)
    # split the video into images, name them using the name from image_filename_list
    frame_count = 0
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        image_filename = image_filename_list[frame_count]
        _, subfolder, image_name = image_filename.split('/')
        subfolder = osp.join(out_driving_folder, subfolder)
        os.makedirs(subfolder, exist_ok=True)
        image_path = osp.join(subfolder, image_name)
        cv2.imwrite(image_path, frame)
        frame_count += 1

# %%
augmented_video_root = '/prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results'
split_image_root='/prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images'
driver = ['atalie', 'keli', 'matt']
driving_video_ver=1

for d in driver:
    augmented_video_subroot = osp.join(augmented_video_root, f'{d}-driving')
    video_paths = os.listdir(augmented_video_subroot)
    video_paths = [p for p in video_paths if '_concat' not in p]
    for video_path in video_paths:
        video_path = osp.join(augmented_video_subroot, video_path)
        print("Now processing: ", video_path)
        print("Saving to: ", split_image_root)
        print("-----------------------------------------------")
        video_to_images(video_path, split_image_root, driving_video_ver=driving_video_ver)
# Out:
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Keli_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Matt_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Michel_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Nicholas_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Ning_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject001_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject002_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject003_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject004_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject005_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject006_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject007_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject008_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject009_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject010_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject011_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject012_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject013_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject014_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject015_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject016_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject017_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject018_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject019_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject020_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject021_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject022_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject023_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject024_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject025_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject026_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject027_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject028_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject029_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject030_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject031_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject032_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject043_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject044_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject067_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject068_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject071_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Yan_lc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/aanbunat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/abhrajit--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/afabela--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/agajalka--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/agarg--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/amirpuri--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/anirudhg--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/ardavanm--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/aschevci--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/bharnara--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/chrimart--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/daniel--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/derekh--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/dhvanis--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/duc--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/ebrahim--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/garima--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/halsadik--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/iherrick--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jcasanov--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jesszhan--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jgirado--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jharyadi--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jiancheng--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jmoganna--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/josucruz--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/jpitta--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/karnagar--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/karsha--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/kasch--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/keli--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/kgohil--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/kiran--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/malston--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/matt--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/mcastell--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/michel--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/mmessiha--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/munoz--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/ning--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/nkulshre--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/page--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/pogorman--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/puxuand--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/ritesh--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/rlai--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/rmacwan--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/rsarvan--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/shamjosh--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/shansrid--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/shaunv--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/spaleti--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/sqiao--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/srimrama--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/susheel--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/svishnub--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/taeheel--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/tianyi--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/tlutton--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/velasco--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/vijayaku--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/vinamada--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/yan--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject040_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject033_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject034_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject035_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject037_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject038_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/atalie-driving/Subject039_olat--atalie.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Keli_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Matt_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Michel_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Nicholas_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Ning_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/aanbunat--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject001_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject002_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject003_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject004_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject005_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject006_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject007_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject008_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject009_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# Now processing:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/llp_results/keli-driving/Subject010_lc--keli.mp4
# Saving to:  /prj/qct/mmrd-cv/wonderland_data/3DFR_Data/3dMD/PAC/live-portrait-data/augmented_images
# -----------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 15
#      13 print("Saving to: ", split_image_root)
#      14 print("-----------------------------------------------")
# ---> 15 video_to_images(video_path, split_image_root, driving_video_ver=driving_video_ver)
#
# Cell In[9], line 37, in video_to_images(input_video_path, split_image_root, driving_video_ver)
#      35 os.makedirs(subfolder, exist_ok=True)
#      36 image_path = osp.join(subfolder, image_name)
# ---> 37 cv2.imwrite(image_path, frame)
#      38 frame_count += 1
#
# KeyboardInterrupt:
